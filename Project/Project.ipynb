# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import requests
from StringIO import StringIO

BLACK = (0,0,0)
RED = (255,0,0)
WHITE = (255,255,255)
pix = 0

class Blob():

    def __init__(self):
        self.blob = []
    def add(self,i,j):
        self.blob.append[(i,j)]
    def mass():
        return len(self.blob)
    def distanceTo(blob):
        distance = sqrt(((self.centerOfMass()[0] - blob.centerOfMass()[0])**2)\
                        + ((self.centerOfMass()[1] - blob.centerOfMass()[1])**2))
    def centerOfMass():
        xtot, ytot = 0, 0
        for pix in self.blob:
            xtot = xtot + pix[0]
            ytot = ytot + pix[1]
        xcm = float(xtot)/float(len(self.blob))
        ycm = float(ytot)/float(len(self.blob))
        return xcm, ycm

def BlobFinder(picture, tau):
    '''find all blobs in the picture using the luminance threshold tau'''
    black = (0, 0, 0)
    white = (255, 255, 255)
    xsize, ysize = im1.size
    temp = im1.load()
    result = 0
    for x in range(xsize):
        for y in range(ysize):
            r,g,b = temp[x,y]
            if r+g+b >= tau:
                result = result + 1
                temp[x,y] = RED
                
                fill(temp,xsize,ysize,x,y)
            else:
                temp[x,y] = BLACK
                
    return blob
                    
def countBeads(P):
    '''return the number of beads with >= P pixels'''
    count = 0
    for blob in range(0,1):
        if blob.mass() >= P:
            count = count + 1
    return count
    
def getBeads(P):
    '''return all beads with >= P pixels'''
    pass
                    
def fill(picture, xsize, ysize, xstart, ystart):
    """keep a list of pixels that need to be looked at, 
    but haven't yet been filled in - a list of the (x,y) 
    coordinates of pixels that are neighbors of ones we have 
    already examined.  Keep looping until there's nothing 
    left in this list"""
    queue = [(xstart,ystart)]
    while queue:
        x,y,queue = queue[0][0], queue[0][1], queue[1:]
        if picture[x,y] == RED:
            picture[x,y] = WHITE
            if x > 0:
                queue.append((x-1,y))
            if x < (xsize-1):
                queue.append((x+1,y))
            if y > 0:
                queue.append((x, y-1))
            if y < (ysize-1):
                queue.append((x, y+1))
             
def allBlobs(P,tau,picture):
    xsize, ysize = im1.size
    temp = im1.load()
    result = 0
    for x in range(xsize):
        for y in range(ysize):
            r,g,b = temp[x,y]
            if r+g+b >= tau:
                result = result + 1
                temp[x,y] = RED
                
                fill(temp,xsize,ysize,x,y)
            else:
                temp[x,y] = BLACK
    

bead = Blob()
global ext
ext = ".jpg"

imageFile = "frame00000.jpg"
im1 = Image.open(imageFile)
print BlobFinder(im1,180)
imshow(im1)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <__main__.Blob instance at 0x0000000010504088>
# WARNING: pylab import has clobbered these variables: ['fill']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import Image

global ext
ext = ".jpg"

imageFile = "frame00000.jpg"
im1 = Image.open(imageFile)
imshow(im1)

# %%
BLACK = (0,0,0)
RED = (255,0,0)
WHITE = (255,255,255)
                
def BlobFinder(picture, tau):
        '''find all blobs in the picture using the luminance threshold tau'''
        black = (0, 0, 0)
        white = (255, 255, 255)
        xsize, ysize = picture.size
        temp = picture.load()
        result = 0
        for x in range(xsize):
            for y in range(ysize):
                r,g,b = temp[x,y]
                if r+g+b >= tau:
                    result = result + 1
                    temp[x,y] = RED
                    fill(temp,xsize,ysize,x,y)
        return result
                    
def fill(picture, xsize, ysize, xstart, ystart):
    """keep a list of pixels that need to be looked at, 
    but haven't yet been filled in - a list of the (x,y) 
    coordinates of pixels that are neighbors of ones we have 
    already examined.  Keep looping until there's nothing 
    left in this list"""
    queue = [(xstart,ystart)]
    while queue:
        x,y,queue = queue[0][0], queue[0][1], queue[1:]
        if picture[x,y] == RED:
            picture[x,y] = WHITE
            if x > 0:
                queue.append((x-1,y))
            if x < (xsize-1):
                queue.append((x+1,y))
            if y > 0:
                queue.append((x, y-1))
            if y < (ysize-1):
                queue.append((x, y+1))
                
import Image

global ext
ext = ".jpg"

imageFile = "frame00000.jpg"
im1 = Image.open(imageFile)
print BlobFinder(im1,180)
imshow(im1)
# Out:
# 3804
