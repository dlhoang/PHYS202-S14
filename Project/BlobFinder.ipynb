# %%
# %pylab inline
import matplotlib.pyplot as plt
from PIL import Image
import requests
from StringIO import StringIO

BLACK = (0,0,0)
RED = (255,0,0)
WHITE = (255,255,255)

class Blob():

    def __init__(self):
        self.blob = []
    def add(self,i,j):
        self.blob.append([i,j])
    def mass():
        return len(self.blob)
    def distanceTo(blob):
        distance = round(sqrt(((self.centerOfMass()[0] - blob.centerOfMass()[0])**2)\
                        + ((self.centerOfMass()[1] - blob.centerOfMass()[1])**2)),4)
    def centerOfMass():
        xtot, ytot = 0, 0
        for pix in self.blob:
            xtot = xtot + pix[0]
            ytot = ytot + pix[1]
        xcm = float(xtot)/float(len(self.blob))
        ycm = float(ytot)/float(len(self.blob))
        return xcm, ycm
    
def BlobFinder(picture, tau):
    '''find all blobs in the picture using the luminance threshold tau'''
    xsize, ysize = picture.size
    temp = picture.load()
    blobs = []
    for x in range(xsize):
        for y in range(ysize):
            r,g,b = temp[x,y]
            if r+g+b >= tau:
                temp[x,y] = RED
                blob = fill(temp,xsize,ysize,x,y)
                blobs.append(blob)
            else:
                temp[x,y] = BLACK
    return blobs
                    
def fill(picture, xsize, ysize, xstart, ystart):
    """keep a list of pixels that need to be looked at, 
    but haven't yet been filled in - a list of the (x,y) 
    coordinates of pixels that are neighbors of ones we have 
    already examined.  Keep looping until there's nothing 
    left in this list"""
    queue = [(xstart,ystart)]
    blob = Blob()
    blob.add(xstart,ystart)
    while queue:
        x,y,queue = queue[0][0], queue[0][1], queue[1:]
        if picture[x,y] == RED:
            picture[x,y] = WHITE
            blob.add(x,y)
            if x > 0:
                queue.append((x-1,y))
            if x < (xsize-1):
                queue.append((x+1,y))
            if y > 0:
                queue.append((x, y-1))
            if y < (ysize-1):
                queue.append((x, y+1))
    return blob
 
                    
def countBeads(P,picture,tau):
    '''return the number of beads with >= P pixels'''
    blob = Blob()
    beads = BlobFinder(picture,tau)
    count = 0
    for blob in beads:
        if blob.mass >= P:
            count = count + 1
    return count
    
def getBeads(P,picture,tau):
    '''return all beads with >= P pixels'''
    blob = Blob()
    beads = BlobFinder(picture,tau)
    blobs = []
    for blob in beads:
        if blob.mass >=P:
            blobs.append(blob)
    return blobs
             
def printBeads(P,picture,tau):
    beads = BlobFinder(picture,tau)
    for bead in beads:
        print "Beads with at least %s pixels" %P
        if bead.mass >= P:
            print "mass: %s" %bead.mass
            print "center of mass: %s" %bead.centerOfMass
    print "All founded beads: "
    for bead in getBeads(P,picture,tau):
        print "mass: %s" %bead.mass
        print "center of mass: %s" %bead.centerOfMass
        
        
global ext
ext = ".jpg"

imageFile = "frame00000.jpg"
im1 = Image.open(imageFile)
BlobFinder(im1,250)
plt.imshow(im1)
countBeads(25,im1,250)
printBeads(25,im1,250)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2588>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2588>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2A88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2A88>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2108>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2108>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2A08>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2A08>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2808>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2808>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2D48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2D48>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2548>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2548>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2D08>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2D08>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2C48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2C48>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2088>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2088>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A26C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A26C8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2F08>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2F08>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2E48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2E48>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A22C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A22C8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2688>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2688>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2788>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2788>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2488>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2488>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2DC8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2DC8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2C88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2C88>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2988>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2988>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2F48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2F48>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2288>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2288>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A25C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A25C8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2948>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2948>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A27C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A27C8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A28C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A28C8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2748>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2748>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5A2608>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5A2608>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A2F2AC8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A2F2AC8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A2F25C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A2F25C8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A2F2F48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A2F2F48>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A2F22C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A2F22C8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A2F2D88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A2F2D88>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A2F2E88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A2F2E88>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A2F2A48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A2F2A48>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A2F2348>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A2F2348>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A2F2608>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A2F2608>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A2F2908>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A2F2908>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A2F2148>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A2F2148>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A2F2188>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A2F2188>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A449088>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A449088>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A449508>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A449508>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A449308>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A449308>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A449148>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A449148>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A449588>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A449588>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A4496C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A4496C8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5C9888>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5C9888>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5C9788>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5C9788>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5C9908>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5C9908>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5C9F88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5C9F88>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5C96C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5C96C8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5C9488>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5C9488>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5C9F48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5C9F48>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5C9208>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5C9208>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A5C9288>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A5C9288>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A14F708>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A14F708>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A391EC8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A391EC8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A391B88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A391B88>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A391088>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A391088>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A391CC8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A391CC8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A391188>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A391188>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A391F48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A391F48>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A391248>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A391248>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A391508>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A391508>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A3914C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A3914C8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A391708>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A391708>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A391A08>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A391A08>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A391548>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A391548>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6C2AC8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6C2AC8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6C2D08>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6C2D08>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6C2E88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6C2E88>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6C27C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6C27C8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6C2D48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6C2D48>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6C2808>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6C2808>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6C2FC8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6C2FC8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6CAA08>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6CAA08>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6CA4C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6CA4C8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6CADC8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6CADC8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6CA8C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6CA8C8>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6CA688>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6CA688>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6CA388>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6CA388>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6CA848>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6CA848>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6CAC08>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6CAC08>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6CAB88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6CAB88>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6CA248>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A6CA248>>
# Beads with at least 25 pixels
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A6
>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A852988>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A852A88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A852A88>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A852B88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A852B88>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A852C88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A852C88>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A852D88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A852D88>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A852E88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A852E88>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A852F88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A852F88>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856188>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856188>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856288>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856288>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856388>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856388>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856488>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856488>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856588>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856588>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856688>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856688>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856788>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856788>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856888>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856888>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856988>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856988>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856A88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856A88>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856B88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856B88>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856C88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856C88>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856D88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856D88>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856E88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856E88>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856F88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856F88>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A856F48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A856F48>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A8571C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A8571C8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A8572C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A8572C8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A8573C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A8573C8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A8574C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A8574C8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A8575C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A8575C8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A8576C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A8576C8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A8577C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A8577C8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A8578C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A8578C8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A8579C8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A8579C8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A857AC8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A857AC8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A857BC8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A857BC8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A857CC8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A857CC8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A857DC8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A857DC8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A857EC8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A857EC8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A857F88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A857F88>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858148>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858148>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858208>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858208>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858308>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858308>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858408>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858408>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858508>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858508>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858608>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858608>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858708>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858708>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858808>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858808>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858908>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858908>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858A08>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858A08>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858B08>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858B08>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858C08>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858C08>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858D08>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858D08>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858E08>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858E08>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858F08>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858F08>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A858FC8>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A858FC8>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859088>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859088>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859248>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859248>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859348>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859348>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859448>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859448>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859548>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859548>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859648>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859648>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859748>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859748>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859848>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859848>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859948>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859948>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859A48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859A48>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859B48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859B48>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859C48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859C48>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859D48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859D48>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859E48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859E48>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859F48>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859F48>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A859E08>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A859E08>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A85A188>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A85A188>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A85A288>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A85A288>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A85A388>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A85A388>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A85A488>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A85A488>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A85A588>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A85A588>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A85A688>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A85A688>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A85A788>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A85A788>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A85A888>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A85A888>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A85A988>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A85A988>>
# mass: <bound method Blob.mass of <__main__.Blob instance at 0x000000000A85AA88>>
# center of mass: <bound method Blob.centerOfMass of <__main__.Blob instance at 0x000000000A85AA88>>
# WARNING: pylab import has clobbered these variables: ['fill']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
def BlobFinder(picture, tau):
        '''find all blobs in the picture using the luminance threshold tau'''
        blobs = []
        xsize, ysize = picture.size
        temp = picture.load()
        result = 0
        for x in range(xsize):
            for y in range(ysize):
                r,g,b = temp[x,y]
                if r+g+b >= tau:
                    temp[x,y] = RED
                    blob = fill(temp,xsize,ysize,x,y)
                    blobs.append(blob)
        return blobs
                    
def fill(picture, xsize, ysize, xstart, ystart):
    queue = [(xstart,ystart)]
    blob = Blob()
    blob.add(xstart,ystart)
    temp = picture.load()
    while queue:
        x,y,queue = queue[0][0], queue[0][1], queue[1:]
        if temp[x,y] == RED:
            temp[x,y] = WHITE
            blob.add(x,y)
            if x > 0:
                queue.append((x-1,y))
            if x < (xsize-1):
                queue.append((x+1,y))
            if y > 0:
                queue.append((x, y-1))
            if y < (ysize-1):
                queue.append((x, y+1))
    return blob

# %%
# %pylab inline

global ext
ext = ".jpg"

imageFile = "frame00000.jpg"
im1 = Image.open(imageFile)
BlobFinder(im1,180)
plt.imshow(im1)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-02089c3f02fe> in <module>()
#       6 imageFile = "frame00000.jpg"
#       7 im1 = Image.open(imageFile)
# ----> 8 BlobFinder(im1,180)
#       9 plt.imshow(im1)
#
# <ipython-input-1-db50de7db1cf> in BlobFinder(picture, tau)
#      41                     result = result + 1
#      42                     temp[x,y] = RED
# ---> 43                     fill(temp,xsize,ysize,x,y)
#      44         return result
#      45
#
# C:\Users\David Nguyen\Anaconda\lib\site-packages\matplotlib\pyplot.pyc in fill(*args, **kwargs)
#    2736         ax.hold(hold)
#    2737     try:
# -> 2738         ret = ax.fill(*args, **kwargs)
#    2739         draw_if_interactive()
#    2740     finally:
#
# C:\Users\David Nguyen\Anaconda\lib\site-packages\matplotlib\axes.pyc in fill(self, *args, **kwargs)
#    6925
#    6926         patches = []
# -> 6927         for poly in self._get_patches_for_fill(*args, **kwargs):
#    6928             self.add_patch(poly)
#    6929             patches.append(poly)
#
# C:\Users\David Nguyen\Anaconda\lib\site-packages\matplotlib\axes.pyc in _grab_next_args(self, *args, **kwargs)
#     324                 isplit = 2
#     325
# --> 326             for seg in self._plot_args(remaining[:isplit], kwargs):
#     327                 yield seg
#     328             remaining = remaining[isplit:]
#
# C:\Users\David Nguyen\Anaconda\lib\site-packages\matplotlib\axes.pyc in _plot_args(self, tup, kwargs)
#     303         ncx, ncy = x.shape[1], y.shape[1]
#     304         for j in xrange(max(ncx, ncy)):
# --> 305             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     306             ret.append(seg)
#     307         return ret
#
# C:\Users\David Nguyen\Anaconda\lib\site-packages\matplotlib\axes.pyc in _makefill(self, x, y, kw, kwargs)
#     267                                facecolor=facecolor,
#     268                                fill=True,
# --> 269                                closed=kw['closed'])
#     270         self.set_patchprops(seg, **kwargs)
#     271         return seg
#
# C:\Users\David Nguyen\Anaconda\lib\site-packages\matplotlib\patches.pyc in __init__(self, xy, closed, **kwargs)
#     806         Patch.__init__(self, **kwargs)
#     807         self._closed = closed
# --> 808         self.set_xy(xy)
#     809
#     810     def get_path(self):
#
# C:\Users\David Nguyen\Anaconda\lib\site-packages\matplotlib\patches.pyc in set_xy(self, xy)
#     831             if len(xy) > 2 and (xy[0] == xy[-1]).all():
#     832                 xy = xy[:-1]
# --> 833         self._path = Path(xy, closed=self._closed)
#     834
#     835     _get_xy = get_xy
#
# C:\Users\David Nguyen\Anaconda\lib\site-packages\matplotlib\path.pyc in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     131             vertices = vertices.astype(np.float_).filled(np.nan)
#     132         else:
# --> 133             vertices = np.asarray(vertices, np.float_)
#     134
#     135         if codes is not None:
#
# C:\Users\David Nguyen\Anaconda\lib\site-packages\numpy\core\numeric.pyc in asarray(a, dtype, order)
#     458
#     459     """
# --> 460     return array(a, dtype, copy=False, order=order)
#     461
#     462 def asanyarray(a, dtype=None, order=None):
#
# TypeError: float() argument must be a string or a number

# %%
BLACK = (0,0,0)
RED = (255,0,0)
WHITE = (255,255,255)
                
def BlobFinder(picture, tau):
        '''find all blobs in the picture using the luminance threshold tau'''
        black = (0, 0, 0)
        white = (255, 255, 255)
        xsize, ysize = picture.size
        temp = picture.load()
        result = 0
        for x in range(xsize):
            for y in range(ysize):
                r,g,b = temp[x,y]
                if r+g+b >= tau:
                    result = result + 1
                    temp[x,y] = RED
                    fill(temp,xsize,ysize,x,y)
        return result
                    
def fill(picture, xsize, ysize, xstart, ystart):
    """keep a list of pixels that need to be looked at, 
    but haven't yet been filled in - a list of the (x,y) 
    coordinates of pixels that are neighbors of ones we have 
    already examined.  Keep looping until there's nothing 
    left in this list"""
    queue = [(xstart,ystart)]
    while queue:
        x,y,queue = queue[0][0], queue[0][1], queue[1:]
        if picture[x,y] == RED:
            picture[x,y] = WHITE
            if x > 0:
                queue.append((x-1,y))
            if x < (xsize-1):
                queue.append((x+1,y))
            if y > 0:
                queue.append((x, y-1))
            if y < (ysize-1):
                queue.append((x, y+1))
                
import Image

global ext
ext = ".jpg"

imageFile = "frame00000.jpg"
im1 = Image.open(imageFile)
print BlobFinder(im1,180)
plt.imshow(im1)
# Out:
# 3804

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import requests
from StringIO import StringIO

BLACK = (0,0,0)
RED = (255,0,0)
WHITE = (255,255,255)

class Blob():

    def __init__(self):
        self.blob = []
    def add(self,i,j):
        self.blob.append([i,j])
    def mass():
        return len(self.blob)
    def distanceTo(blob):
        distance = round(sqrt(((self.centerOfMass()[0] - blob.centerOfMass()[0])**2)\
                        + ((self.centerOfMass()[1] - blob.centerOfMass()[1])**2)),4)
    def centerOfMass():
        xtot, ytot = 0, 0
        for pix in self.blob:
            xtot = xtot + pix[0]
            ytot = ytot + pix[1]
        xcm = float(xtot)/float(len(self.blob))
        ycm = float(ytot)/float(len(self.blob))
        return xcm, ycm

def monochrome(picture, tau):
    xsize, ysize = picture.size
    temp = picture.load()
    for x in range(xsize):
        for y in range(ysize):
            r,g,b = temp[x,y]
            if r+g+b <= tau: 
                temp[x,y] = BLACK
            else:
                temp[x,y] = RED
                fill(temp,xsize,ysize,x,y)
    
def fill(picture, xsize, ysize, xstart, ystart):
    queue = [(xstart,ystart)]
    blob = Blob()
    blob.add(xstart,ystart)
    temp = picture.load()
    while queue:
        x,y,queue = queue[0][0], queue[0][1], queue[1:]
        if temp[x,y] == RED:
            temp[x,y] = WHITE
            if x > 0:
                queue.append((x-1,y))
            if x < (xsize-1):
                queue.append((x+1,y))
            if y > 0:
                queue.append((x, y-1))
            if y < (ysize-1):
                queue.append((x, y+1))
    return blob
                
                
def BlobFinder(picture, tau):
    '''find all blobs in the picture using the luminance threshold tau'''
    blobs = []   
    blob = fill(picture, tau)
    blobs.append(blob)
    return beads

# %%
import Image

global ext
ext = ".jpg"

imageFile = "frame00000.jpg"
im1 = Image.open(imageFile)
print BlobFinder(im1,180)
plt.imshow(im1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-871a442f2567> in <module>()
#       6 imageFile = "frame00000.jpg"
#       7 im1 = Image.open(imageFile)
# ----> 8 print BlobFinder(im1,180)
#       9 plt.imshow(im1)
#
# <ipython-input-62-313ca2a26313> in BlobFinder(picture, tau)
#      63     '''find all blobs in the picture using the luminance threshold tau'''
#      64     blobs = []
# ---> 65     blob = fill(picture, tau)
#      66     blobs.append(blob)
#      67     return beads
#
# TypeError: fill() takes exactly 5 arguments (2 given)
