# %%
# %%file BlobFinder.py

import matplotlib.pyplot as plt
from PIL import Image
import requests
from StringIO import StringIO

# define colors
BLACK = (0,0,0)
RED = (255,0,0)
WHITE = (255,255,255)

# creating a blob
class Blob():

    def __init__(self):
        """ initializes a blob """
        self.blob = []
    def add(self,i,j):
        """ adds (x,y) position of a pixel that is part of a blob """
        self.blob.append([i,j])
    def mass(self):
        """ returns mass of a blob determined by how many pixels it contains """
        return len(self.blob)

    def distanceTo(self,blob):
        """ returns distance from current blob to blob being passed in """
        distance = round((((self.centerOfMass()[0] - blob.centerOfMass()[0])**2)\
                        + ((self.centerOfMass()[1] - blob.centerOfMass()[1])**2))**0.5,4)
        return distance

    def centerOfMass(self):
        """ returns (x,y) position of center of mass (center) of blob """
        xtot, ytot = 0, 0
        for pix in self.blob:
            xtot = xtot + pix[0]
            ytot = ytot + pix[1]
        xcm = float(xtot)/float(len(self.blob))
        ycm = float(ytot)/float(len(self.blob))
        return xcm, ycm

def monochrome(picture,tau):
    """ turns blobs in a picture red using luminance threshold tau and turn background noise black """
    xsize, ysize = picture.size
    temp = picture.load()
    for x in range(xsize):
        for y in range(ysize):
            r,g,b = temp[x,y]
            # if color is higher than luminance threshold, consider a blob and turn red
            if (r+g+b)/3 <= tau:
                temp[x,y] = RED
            # else consider background noise and turn black
            else:
                temp[x,y] = BLACK

def BlobFinder(picture, tau):
    """ returns a list of all blobs in the picture using the luminance threshold tau """
    # turns picture red and black first
    monochrome(picture,tau)
    xsize, ysize = picture.size
    temp = picture.load()
    blobs = []
    for x in range(xsize):
        for y in range(ysize):
            # find blobs in picture and add to list of blobs
            if temp[x,y] == RED:
                blob = Fill(temp,xsize,ysize,x,y)
                blobs.append(blob)
    return blobs
    
def Fill(picture, xsize, ysize, xstart, ystart):
    """ keep a list of pixels that need to be looked at, 
    but haven't yet been filled in - a list of the (x,y) 
    coordinates of pixels that are neighbors of ones we have 
    already examined.  Keep looping until there's nothing 
    left in this list. Finally returns the blob. """
    # create a blob
    blob = Blob()
    queue = [(xstart,ystart)]
    # add the first red pixel found
    blob.add(xstart,ystart)
    while queue:
        x,y,queue = queue[0][0], queue[0][1], queue[1:]
        # if neighboring pixel is red, add to queue, fill white, and add to blob object
        if picture[x,y] == RED:
            picture[x,y] = WHITE
            blob.add(x,y)
            if x > 0:
                queue.append((x-1,y))
            if x < (xsize-1):
                queue.append((x+1,y))
            if y > 0:
                queue.append((x, y-1))
            if y < (ysize-1):
                queue.append((x, y+1))
    return blob
 
                    
def countBeads(P,picture,tau):
    """ returns the number of blobs with mass >= P pixels """
    # get all blobs in a picture with luminance threshold tau
    beads = BlobFinder(picture,tau)
    count = 0
    # loop through all blobs -- if mass >= P, increment count
    for bead in beads:
        if bead.mass() >= P:
            count = count + 1
    return count
    
def getBeads(P,picture,tau):
    """ returns a list of all blobs with mass >= P pixels """
    # get all blobs in a picture with luminance threshold tau
    beads = BlobFinder(picture,tau)
    # initialize a list of blobs
    blobs = []
    # loop through all blobs -- if mass >= P, add blob to list of blobs
    for bead in beads:
        if bead.mass() >=P:
            blobs.append(bead)
    return blobs
             
def printBeads(P,picture,tau):
    """ first print mass and corresponding center of mass of blobs with mass >= P,
    then print mass and corresponding center of mass of all blobs found regardless """
    # get all blobs in a picture with luminance threshold tau
    beads = BlobFinder(picture,tau)

    # print characteristics of blobs with mass >= P
    print "Beads with at least %s pixels" %P
    for bead in beads:
        if bead.mass() >= P:
            print "mass: %s" %bead.mass()
            print "center of mass: %s %s" %bead.centerOfMass()
            
    # print characteristics of all blobs found
    print "All founded beads: "
    for bead in beads:
        print "mass: %s" %bead.mass()
        print "center of mass: %s %s" %bead.centerOfMass()
# Out:
# Overwriting BlobFinder.py

# %%
# global ext
# ext = ".jpg"

# %pylab inline
imageFile = "run4/Movie_01_T0003.jpg"
im1 = Image.open(imageFile)
BlobFinder(im1,200)
print countBeads(25,im1,200)
getBeads(25,im1,200)
printBeads(25,im1,200)
plt.imshow(im1)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 12
# Beads with at least 25 pixels
# mass: 288615
# center of mass: 312.572011157 237.679295948
# mass: 25
# center of mass: 1.68 439.24
# mass: 30
# center of mass: 23.9666666667 471.466666667
# mass: 35
# center of mass: 113.742857143 251.6
# mass: 44
# center of mass: 170.863636364 464.227272727
# mass: 40
# center of mass: 182.75 330.65
# mass: 111
# center of mass: 354.684684685 302.351351351
# mass: 46
# center of mass: 545.108695652 383.456521739
# mass: 26
# center of mass: 557.307692308 365.0
# mass: 45
# center of mass: 571.466666667 446.2
# mass: 470
# center of mass: 624.334042553 236.3
# mass: 25
# center of mass: 636.76 185.36
# All founded beads:
# mass: 288615
# center of mass: 312.572011157 237.679295948
# mass: 25
# center of mass: 1.68 439.24
# mass: 30
# center of mass: 23.9666666667 471.466666667
# mass: 17
# center of mass: 88.6470588235 319.0
# mass: 16
# center of mass: 89.9375 450.5625
# mass: 35
# center of mass: 113.742857143 251.6
# mass: 2
# center of mass: 113.0 18.0
# mass: 2
# center of mass: 124.0 116.0
# mass: 4
# center of mass: 146.0 436.75
# mass: 44
# center of mass: 170.863636364 464.227272727
# mass: 40
# center of mass: 182.75 330.65
# mass: 2
# center of mass: 199.0 457.0
# mass: 6
# center of mass: 200.0 458.666666667
# mass: 2
# center of mass: 200.0 462.0
# mass: 4
# center of mass: 218.25 33.25
# mass: 2
# center of mass: 234.0 216.0
# mass: 2
# center of mass: 240.0 220.0
# mass: 9
# center of mass: 247.555555556 332.777777778
# mass: 21
# center of mass: 261.333333333 383.857142857
# mass: 12
# center of mass: 261.083333333 288.666666667
# mass: 14
# center of mass: 344.785714286 85.8571428571
# mass: 111
# center of mass: 354.684684685 302.351351351
# mass: 5
# center of mass: 357.8 0.2
# mass: 6
# center of mass: 362.833333333 236.0
# mass: 2
# center of mass: 366.0 122.0
# mass: 11
# center of mass: 387.818181818 399.090909091
# mass: 5
# center of mass: 392.2 430.8
# mass: 9
# center of mass: 411.777777778 274.777777778
# mass: 20
# center of mass: 417.0 113.55
# mass: 5
# center of mass: 432.8 384.2
# mass: 14
# center of mass: 438.0 388.071428571
# mass: 18
# center of mass: 458.333333333 447.055555556
# mass: 2
# center of mass: 465.0 263.0
# mass: 2
# center of mass: 480.0 460.0
# mass: 15
# center of mass: 487.4 295.666666667
# mass: 24
# center of mass: 488.75 161.916666667
# mass: 10
# center of mass: 509.8 383.6
# mass: 2
# center of mass: 521.0 176.0
# mass: 14
# center of mass: 523.285714286 29.2857142857
# mass: 8
# center of mass: 522.875 373.25
# mass: 2
# center of mass: 528.0 11.0
# mass: 16
# center of mass: 540.3125 249.5
# mass: 46
# center of mass: 545.108695652 383.456521739
# mass: 2
# center of mass: 546.0 276.0
# mass: 26
# center of mass: 557.307692308 365.0
# mass: 2
# center of mass: 560.0 392.0
# mass: 4
# center of mass: 564.5 277.25
# mass: 45
# center of mass: 571.466666667 446.2
# mass: 3
# center of mass: 570.0 467.333333333
# mass: 2
# center of mass: 573.0 454.0
# mass: 9
# center of mass: 576.0 86.7777777778
# mass: 2
# center of mass: 582.0 231.0
# mass: 2
# center of mass: 583.0 222.0
# mass: 3
# center of mass: 585.333333333 264.0
# mass: 2
# center of mass: 594.0 71.0
# mass: 9
# center of mass: 594.777777778 197.0
# mass: 8
# center of mass: 596.875 430.25
# mass: 2
# center of mass: 596.0 445.0
# mass: 13
# center of mass: 600.0 189.153846154
# mass: 18
# center of mass: 599.833333333 292.777777778
# mass: 2
# center of mass: 599.0 444.0
# mass: 2
# center of mass: 600.0 288.0
# mass: 3
# center of mass: 600.0 442.333333333
# mass: 6
# center of mass: 601.666666667 219.5
# mass: 2
# center of mass: 601.0 451.0
# mass: 2
# center of mass: 602.0 444.0
# mass: 3
# center of mass: 602.333333333 448.0
# mass: 2
# center of mass: 605.0 271.0
# mass: 7
# center of mass: 605.285714286 278.285714286
# mass: 2
# center of mass: 605.0 288.0
# mass: 5
# center of mass: 606.4 223.8
# mass: 2
# center of mass: 606.0 284.0
# mass: 8
# center of mass: 607.25 286.75
# mass: 2
# center of mass: 607.0 281.0
# mass: 2
# center of mass: 607.0 285.0
# mass: 3
# center of mass: 608.333333333 218.0
# mass: 3
# center of mass: 609.0 185.333333333
# mass: 4
# center of mass: 609.5 215.25
# mass: 2
# center of mass: 609.0 244.0
# mass: 2
# center of mass: 609.0 284.0
# mass: 10
# center of mass: 610.0 292.5
# mass: 9
# center of mass: 611.0 218.444444444
# mass: 17
# center of mass: 611.705882353 403.764705882
# mass: 3
# center of mass: 611.0 235.333333333
# mass: 2
# center of mass: 611.0 289.0
# mass: 12
# center of mass: 612.25 296.583333333
# mass: 470
# center of mass: 624.334042553 236.3
# mass: 2
# center of mass: 614.0 221.0
# mass: 2
# center of mass: 614.0 227.0
# mass: 4
# center of mass: 615.25 184.25
# mass: 2
# center of mass: 616.0 189.0
# mass: 23
# center of mass: 617.956521739 213.217391304
# mass: 7
# center of mass: 617.0 283.142857143
# mass: 3
# center of mass: 619.333333333 303.0
# mass: 2
# center of mass: 619.0 305.0
# mass: 13
# center of mass: 622.846153846 374.538461538
# mass: 2
# center of mass: 622.0 185.0
# mass: 12
# center of mass: 623.333333333 294.833333333
# mass: 3
# center of mass: 623.0 304.333333333
# mass: 2
# center of mass: 624.0 217.0
# mass: 24
# center of mass: 628.166666667 137.75
# mass: 2
# center of mass: 627.0 190.0
# mass: 2
# center of mass: 627.0 252.0
# mass: 2
# center of mass: 627.0 309.0
# mass: 14
# center of mass: 628.428571429 377.785714286
# mass: 2
# center of mass: 628.0 307.0
# mass: 4
# center of mass: 629.25 187.5
# mass: 2
# center of mass: 630.0 191.0
# mass: 4
# center of mass: 630.75 312.0
# mass: 3
# center of mass: 632.333333333 314.0
# mass: 25
# center of mass: 636.76 185.36
# mass: 3
# center of mass: 633.0 252.333333333
# mass: 5
# center of mass: 633.4 317.0
# mass: 2
# center of mass: 633.0 378.0
# mass: 2
# center of mass: 635.0 246.0
# mass: 11
# center of mass: 636.363636364 381.727272727
# mass: 2
# center of mass: 636.0 247.0
# mass: 2
# center of mass: 638.0 244.0
# mass: 5
# center of mass: 638.6 320.0
# mass: 2
# center of mass: 639.0 245.0
# mass: 2
# center of mass: 639.0 462.0

# %%
# %pylab inline
imageFile = "run4/Movie_01_T0004.jpg"
im1 = Image.open(imageFile)
BlobFinder(im1,200)
print countBeads(25,im1,200)
getBeads(25,im1,200)
printBeads(25,im1,200)
plt.imshow(im1)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 10
# Beads with at least 25 pixels
# mass: 289524
# center of mass: 312.938081126 237.739061356
# mass: 26
# center of mass: 24.0769230769 471.576923077
# mass: 31
# center of mass: 113.870967742 251.612903226
# mass: 40
# center of mass: 182.45 330.625
# mass: 51
# center of mass: 338.980392157 124.137254902
# mass: 111
# center of mass: 354.648648649 302.567567568
# mass: 46
# center of mass: 544.869565217 383.52173913
# mass: 27
# center of mass: 557.222222222 365.148148148
# mass: 45
# center of mass: 571.311111111 446.4
# mass: 470
# center of mass: 624.40212766 236.640425532
# All founded beads:
# mass: 289524
# center of mass: 312.938081126 237.739061356
# mass: 26
# center of mass: 24.0769230769 471.576923077
# mass: 4
# center of mass: 43.5 450.75
# mass: 2
# center of mass: 55.0 32.0
# mass: 13
# center of mass: 90.0769230769 450.307692308
# mass: 31
# center of mass: 113.870967742 251.612903226
# mass: 10
# center of mass: 145.8 436.2
# mass: 40
# center of mass: 182.45 330.625
# mass: 9
# center of mass: 200.444444444 459.333333333
# mass: 7
# center of mass: 218.0 33.8571428571
# mass: 2
# center of mass: 229.0 348.0
# mass: 3
# center of mass: 234.333333333 215.0
# mass: 2
# center of mass: 246.0 335.0
# mass: 2
# center of mass: 247.0 336.0
# mass: 23
# center of mass: 261.652173913 384.695652174
# mass: 3
# center of mass: 269.333333333 71.0
# mass: 2
# center of mass: 291.0 368.0
# mass: 5
# center of mass: 319.8 410.2
# mass: 5
# center of mass: 334.8 152.2
# mass: 3
# center of mass: 334.0 395.333333333
# mass: 51
# center of mass: 338.980392157 124.137254902
# mass: 14
# center of mass: 344.5 86.3571428571
# mass: 3
# center of mass: 348.0 137.333333333
# mass: 111
# center of mass: 354.648648649 302.567567568
# mass: 3
# center of mass: 362.333333333 236.0
# mass: 2
# center of mass: 367.0 120.0
# mass: 3
# center of mass: 391.333333333 432.0
# mass: 3
# center of mass: 393.0 430.333333333
# mass: 7
# center of mass: 411.428571429 274.857142857
# mass: 2
# center of mass: 431.0 384.0
# mass: 2
# center of mass: 433.0 384.0
# mass: 16
# center of mass: 437.5 388.6875
# mass: 5
# center of mass: 479.6 460.0
# mass: 7
# center of mass: 487.0 296.714285714
# mass: 2
# center of mass: 487.0 295.0
# mass: 8
# center of mass: 509.875 383.625
# mass: 3
# center of mass: 520.333333333 176.0
# mass: 11
# center of mass: 523.090909091 29.4545454545
# mass: 9
# center of mass: 522.777777778 372.777777778
# mass: 46
# center of mass: 544.869565217 383.52173913
# mass: 27
# center of mass: 557.222222222 365.148148148
# mass: 45
# center of mass: 571.311111111 446.4
# mass: 2
# center of mass: 568.0 277.0
# mass: 3
# center of mass: 577.0 441.333333333
# mass: 7
# center of mass: 580.857142857 45.4285714286
# mass: 2
# center of mass: 592.0 192.0
# mass: 13
# center of mass: 595.307692308 197.153846154
# mass: 17
# center of mass: 599.411764706 293.411764706
# mass: 3
# center of mass: 601.333333333 220.0
# mass: 2
# center of mass: 603.0 61.0
# mass: 5
# center of mass: 605.6 221.6
# mass: 5
# center of mass: 607.4 224.4
# mass: 13
# center of mass: 609.692307692 216.846153846
# mass: 470
# center of mass: 624.40212766 236.640425532
# mass: 6
# center of mass: 612.833333333 296.833333333
# mass: 2
# center of mass: 613.0 191.0
# mass: 6
# center of mass: 613.666666667 221.833333333
# mass: 2
# center of mass: 614.0 184.0
# mass: 2
# center of mass: 615.0 183.0
# mass: 5
# center of mass: 616.6 283.0
# mass: 20
# center of mass: 618.75 213.8
# mass: 11
# center of mass: 623.363636364 295.727272727
# mass: 6
# center of mass: 622.833333333 376.0
# mass: 3
# center of mass: 623.0 304.333333333
# mass: 5
# center of mass: 624.4 184.4
# mass: 22
# center of mass: 627.909090909 137.545454545
# mass: 3
# center of mass: 627.0 313.333333333
# mass: 16
# center of mass: 629.3125 377.3125
# mass: 2
# center of mass: 632.0 251.0
# mass: 10
# center of mass: 636.0 380.3
# mass: 5
# center of mass: 638.4 320.4
